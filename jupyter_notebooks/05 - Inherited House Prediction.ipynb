# %% [markdown]
# # Inherited House Prediction Notebook

# %% [markdown]
# ## Objectives
#
# * Answer business requirement 2 with the prediction of the sale price for the four inherited properties.
#
# ## Inputs
#
# * inherited_houses.csv
# * ml_pipeline/predict_saleprice/extra_trees_pipeline.pkl
#
# ## Outputs
#
# * The predicted sale price for the inherited houses.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %%
import os
current_dir = os.getcwd()
current_dir

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")

# %%
current_dir = os.getcwd()
current_dir

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(f"inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/inherited_houses.csv")
df.head()

# %% [markdown]
# ## Load Pipeline

# %%
import joblib

pipeline = joblib.load("outputs/ml_pipeline/predict_saleprice/extra_trees_pipeline.pkl")

# %% [markdown]
# ---

# %% [markdown]
# ## Predict Sale Price

# %%
inherited_house_predictions = pipeline.predict(df)
inherited_house_predictions

# %% [markdown]
# Display predicted Sale Price

# %%
df['PredictedSalePrice'] = inherited_house_predictions.round(2)

features = ['OverallQual', 'GrLivArea', 'KitchenQual', 'YearBuilt', 'GarageArea', '1stFlrSF', 'TotalBsmtSF']
df[features + ['PredictedSalePrice']]

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo
